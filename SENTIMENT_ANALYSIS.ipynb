# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.3.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.3)

# %%
import pandas as pd
from textblob import TextBlob

# %%
data = {
    "text": [
        "I love this product!",
        "This is the worst experience ever",
        "Amazing service and friendly staff",
        "I am not happy with the quality",
        "It is okay, not bad",
        "Absolutely fantastic!",
        "Very disappointing"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                                  text
# 0                I love this product!
# 1   This is the worst experience ever
# 2  Amazing service and friendly staff
# 3     I am not happy with the quality
# 4                 It is okay, not bad
# 5               Absolutely fantastic!
# 6                  Very disappointing

# %%
def get_sentiment(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# %%
df["Sentiment"] = df["text"].apply(get_sentiment)
df
# Out:
#                                  text Sentiment
# 0                I love this product!  Positive
# 1   This is the worst experience ever  Negative
# 2  Amazing service and friendly staff  Positive
# 3     I am not happy with the quality  Negative
# 4                 It is okay, not bad  Positive
# 5               Absolutely fantastic!  Positive
# 6                  Very disappointing  Negative

# %%
df["Sentiment"].value_counts()
# Out:
# Sentiment
# Positive    4
# Negative    3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df["Sentiment"].value_counts().plot(kind='bar')
plt.title("Sentiment Analysis Results")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
